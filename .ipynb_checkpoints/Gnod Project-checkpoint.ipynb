# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import sleep
from random import randint

# %%
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")
# soup

# %%
artist = []
for a in soup.select(".artist"):
    artist.append(a.get_text())

# %%
title = []
for a in soup.select(".title"):
    title.append(a.get_text())

# %%
songs = pd.DataFrame({"title":title,
                       "artist":artist,
                      })

# %%
songs
# Out:
#                                             title  \
# 0                      Rich Men North of Richmond
# 1                                  Margaritaville
# 2                                     Come Monday
# 3   I Remember Everything (feat. Kacey Musgraves)
# 4                              Paint The Town Red
# ..                                            ...
# 93                                     Everywhere
# 94                             Walkin' On the Sun
# 95                         One Particular Harbour
# 96                       Barbie World (with Aqua)
# 97                                      Good Good
#
#                               artist
# 0               Oliver Anthony Music
# 1                      Jimmy Buffett
# 2                      Jimmy Buffett
# 3                         Zach Bryan
# 4                           Doja Cat
# ..                               ...
# 93                     Fleetwood Mac
# 94                       Smash Mouth
# 95                     Jimmy Buffett
# 96           Nicki Minaj & Ice Spice
# 97  USHER, Summer Walker & 21 Savage
#
# [98 rows x 2 columns]

# %%
songs.index = songs.index + 1
songs.index
# Out:
# RangeIndex(start=1, stop=99, step=1)

# %%
songs
# Out:
#                                             title  \
# 1                      Rich Men North of Richmond
# 2                                  Margaritaville
# 3                                     Come Monday
# 4   I Remember Everything (feat. Kacey Musgraves)
# 5                              Paint The Town Red
# ..                                            ...
# 94                                     Everywhere
# 95                             Walkin' On the Sun
# 96                         One Particular Harbour
# 97                       Barbie World (with Aqua)
# 98                                      Good Good
#
#                               artist
# 1               Oliver Anthony Music
# 2                      Jimmy Buffett
# 3                      Jimmy Buffett
# 4                         Zach Bryan
# 5                           Doja Cat
# ..                               ...
# 94                     Fleetwood Mac
# 95                       Smash Mouth
# 96                     Jimmy Buffett
# 97           Nicki Minaj & Ice Spice
# 98  USHER, Summer Walker & 21 Savage
#
# [98 rows x 2 columns]

# %%
song_name = input("Please enter the name of a song: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    print(f"You entered a valid song name: {song_name}")
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: december
# You entered a valid song name: december

# %%
artist_name = input("Please enter the name of the artist: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in artist_name):
    print(f"You entered a valid artist name: {artist_name}")
else:
    print("Invalid input. Please enter an artist name containing letters and/or numbers.")
# Out:
# Please enter the name of the artist: august
# You entered a valid artist name: august

# %%
# Check if the input exists in our df
if song_name.lower() in songs['title'].str.lower().values:
    print(f"{song_name} exists in the data frame.")
else:
    print(f"{song_name} does not exist in the data frame.")
# Out:
# december does not exist in the data frame.

# %%
songs.to_csv('datasongs.csv', index=False)

# %% [markdown]
# ## Song recommender - MVP

# %%
import pandas as pd

data = songs
df = pd.DataFrame(data)

song_name = input("Please enter the name of a song: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    song_name = song_name.lower()

    matching_song = df[(df['title'].str.lower() == song_name)]

    if not matching_song.empty:
        print(f"The song '{matching_song['title'].values[0]}' by {matching_song['artist'].values[0]} matches your input.")

        recommended_song = df[df['title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song['title'].values[0]}' by {recommended_song['artist'].values[0]}")
    else:
        print(f"No match found for the song: {song_name}")
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: maria
# No match found for the song: maria

# %%
pd.set_option('display.max_rows', None)
songs
# Out:
#                                                 title  \
# 1                          Rich Men North of Richmond
# 2                                      Margaritaville
# 3                                         Come Monday
# 4       I Remember Everything (feat. Kacey Musgraves)
# 5                                  Paint The Town Red
# 6                                        Dream Weaver
# 7                                       Lil Boo Thang
# 8                                            Fast Car
# 9                                               Angry
# 10                                   Used To Be Young
# 11                           Cheeseburger In Paradise
# 12                                         Last Night
# 13         Changes In Latitudes, Changes In Attitudes
# 14                            A Pirate Looks at Forty
# 15                                       Cruel Summer
# 16                                        White Horse
# 17                                           All Star
# 18                                      Love Is Alive
# 19                                    Dance The Night
# 20                                       Need A Favor
# 21                                Last Time I Saw You
# 22                                           Pressure
# 23                           Try That In A Small Town
# 24                                  I Want to go Home
# 25                               Watermelon Moonshine
# 26                                       Lose Control
# 27                                      90 some Chevy
# 28                                   Thinkin’ Bout Me
# 29                                           Rockstar
# 30                       Save Me (with Lainey Wilson)
# 31                                            Flowers
# 32                 It's Five O'Clock Somewhere (Live)
# 33                           Son of a Son of a Sailor
# 34                                        Religiously
# 35                                          Calm Down
# 36                                             Dreams
# 37                                            vampire
# 38                                   Used To Be Young
# 39                                  Aint Gotta Dollar
# 40                                    Love You Anyway
# 41                                      Indiana Jones
# 42                                               Fins
# 43  What Was I Made For? [From The Motion Picture ...
# 44                                     Beat You There
# 45                                  How You Remind Me
# 46                                       In Your Love
# 47                                      Enter Sandman
# 48                                     Southern Cross
# 49                      Driving Back There in My Mind
# 50                                     I'm a Believer
# 51                                         Photograph
# 52                                      Forever Young
# 53                                           Far Away
# 54            Something in the Orange (Z&E's Version)
# 55                                        Single Soon
# 56                                    Son Of A Sinner
# 57                        Have You Ever Seen the Rain
# 58                                 Walkin' On the Sun
# 59                                           Daylight
# 60                                          TRUCK BED
# 61   It's Five O'Clock Somewhere (with Jimmy Buffett)
# 62                                  Everything I Love
# 63                                  I'll Stand By You
# 64                                  Latinos For Trump
# 65     We Don't Fight Anymore (feat. Chris Stapleton)
# 66                               Pretty Little Poison
# 67                                           All Star
# 68              Hey Driver (feat. The War and Treaty)
# 69                                           Rhiannon
# 70                                      Keep Going Up
# 71                                              Gypsy
# 72                                  Tennessee Whiskey
# 73                              Southern Cross (Live)
# 74                                    bad idea right?
# 75                                 Walkin' On the Sun
# 76                               90 Some Chevy (Live)
# 77                   Bury Me in Georgia (Single Edit)
# 78                                          Whiteboyz
# 79                                         Dial Drunk
# 80                                     I Love My Body
# 81                                            Volcano
# 82                                   Bring Me to Life
# 83                             Why Don't We Get Drunk
# 84                   Hard to Say I'm Sorry / Get Away
# 85                                             Snooze
# 86                                          Anti-Hero
# 87  Praise (feat. Brandon Lake, Chris Brown & Chan...
# 88                               Ive Got to Get Sober
# 89                                Trip Around the Sun
# 90                             You're the Inspiration
# 91                           I Want To Go Home (live)
# 92                                  Spirit In the Sky
# 93                I Know a Girl Who Sees Me As Poorer
# 94                                         Everywhere
# 95                                 Walkin' On the Sun
# 96                             One Particular Harbour
# 97                           Barbie World (with Aqua)
# 98                                          Good Good
#
#                                           artist
# 1                           Oliver Anthony Music
# 2                                  Jimmy Buffett
# 3                                  Jimmy Buffett
# 4                                     Zach Bryan
# 5                                       Doja Cat
# 6                                    Gary Wright
# 7                                   Paul Russell
# 8                                     Luke Combs
# 9                             The Rolling Stones
# 10                                   Miley Cyrus
# 11                                 Jimmy Buffett
# 12                                 Morgan Wallen
# 13                                 Jimmy Buffett
# 14                                 Jimmy Buffett
# 15                                  Taylor Swift
# 16                               Chris Stapleton
# 17                                   Smash Mouth
# 18                                   Gary Wright
# 19                                      Dua Lipa
# 20                                    Jelly Roll
# 21                                   Nicki Minaj
# 22                                 Zhang Zhe Han
# 23                                  Jason Aldean
# 24                          Oliver Anthony Music
# 25                                 Lainey Wilson
# 26                                   Teddy Swims
# 27                          Oliver Anthony Music
# 28                                 Morgan Wallen
# 29                                    Nickelback
# 30                                    Jelly Roll
# 31                                   Miley Cyrus
# 32                                 Jimmy Buffett
# 33                                 Jimmy Buffett
# 34                              Bailey Zimmerman
# 35                           Rema & Selena Gomez
# 36                                 Fleetwood Mac
# 37                                Olivia Rodrigo
# 38                                   Miley Cyrus
# 39                          Oliver Anthony Music
# 40                                    Luke Combs
# 41                                       Wayland
# 42                                 Jimmy Buffett
# 43                                 Billie Eilish
# 44                                  Will Dempsey
# 45                                    Nickelback
# 46                                Tyler Childers
# 47                                     Metallica
# 48                         Crosby, Stills & Nash
# 49                               Miranda Lambert
# 50                                   Smash Mouth
# 51                                    Nickelback
# 52                                   Rod Stewart
# 53                                    Nickelback
# 54                                    Zach Bryan
# 55                                  Selena Gomez
# 56                                    Jelly Roll
# 57                  Creedence Clearwater Revival
# 58                                   Smash Mouth
# 59                                 David Kushner
# 60                                         HARDY
# 61                                  Alan Jackson
# 62                                 Morgan Wallen
# 63                                    Pretenders
# 64                                 Trump Latinos
# 65                                  Carly Pearce
# 66                                Warren Zeiders
# 67                                   Smash Mouth
# 68                                    Zach Bryan
# 69                                 Fleetwood Mac
# 70  Timbaland, Nelly Furtado & Justin Timberlake
# 71                                 Fleetwood Mac
# 72                               Chris Stapleton
# 73                                 Jimmy Buffett
# 74                                Olivia Rodrigo
# 75                                   Smash Mouth
# 76                          Oliver Anthony Music
# 77                                    Kane Brown
# 78                  Tom MacDonald & Adam Calhoun
# 79                      Noah Kahan & Post Malone
# 80                                         HWASA
# 81                                 Jimmy Buffett
# 82                                   Evanescence
# 83                                 Jimmy Buffett
# 84                                       Chicago
# 85                                           SZA
# 86                                  Taylor Swift
# 87                             Elevation Worship
# 88                          Oliver Anthony Music
# 89               Jimmy Buffett & Martina McBride
# 90                                       Chicago
# 91                          Oliver Anthony Music
# 92                              Norman Greenbaum
# 93                                       Vy Napi
# 94                                 Fleetwood Mac
# 95                                   Smash Mouth
# 96                                 Jimmy Buffett
# 97                       Nicki Minaj & Ice Spice
# 98              USHER, Summer Walker & 21 Savage

# %% [markdown]
# ### Part 2 of Lab

# %%
url2 = "https://www.poplist.de/"

# %%
response = requests.get(url2)
response.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response.content, "html.parser")
#soup2

# %%
iterations = range(1, 6)
#[i for i in iterations]
for i in iterations:
    page= str(i)
    url = "https://www.poplist.de/"+page
    print(url)
# Out:
# https://www.poplist.de/1
# https://www.poplist.de/2
# https://www.poplist.de/3
# https://www.poplist.de/4
# https://www.poplist.de/5

# %%
pages = []

for i in iterations:
    # assemble the url:
    start_at= str(i)
    url = "https://www.poplist.de/poplist.php?site="+start_at+"&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list"
    # download html with a get request:
    response = requests.get(url)
    #response = requests.get(url, headers = {"Accept-Language": "en-US"})

    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))
    print(url)
    # store response into "pages" list
    pages.append(response)

    # respectful nap:
    wait_time = randint(1,4)
    print("I will sleep for " + str(wait_time) + " second/s.")
    sleep(wait_time)
# Out:
# Status code: 200
# https://www.poplist.de/poplist.php?site=1&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 3 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=2&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 2 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=3&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 3 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=4&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 1 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=5&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 2 second/s.

# %%
soup = BeautifulSoup(pages[0].content, "html.parser")

# %%
#soup

# %%
#Artist
#listcontainer > table > tbody > tr:nth-child(2) > td.bestlist.thick > a

#Song
#listcontainer > table > tbody > tr:nth-child(2) > td:nth-child(8) > a

# %%
soup.select("td.bestlist.thick > a")[1].get_text()
# Out:
# 'The Rolling Stones'

# %%
soup.select("td.bestlist.thick > a")[0].get_text()
# Out:
# ' Bob Dylan'

# %%
#print(BeautifulSoup(pages[0].content, "html.parser").prettify())

# %%
titles = []
iters = range(2,102)

for i in range (len(pages)):
    parsed = BeautifulSoup(pages[i].content, "html.parser")
    for j in soup.select("td:nth-child(8) > a"):
         titles.append(j.get_text())

# %%
len(titles)
# Out:
# 500

# %%
artists = []
iters = range(2,102)

for i in range (len(pages)):
    parsed = BeautifulSoup(pages[i].content, "html.parser")
    for j in soup.select("td.bestlist.thick > a"):
         artists.append(j.get_text())

# %%
# artists

# %%
top500 = pd.DataFrame({"artists":artists,
                       "title":titles,
                      })

# %%
# top500

# %%
top500.index = top500.index + 1
top500.index
# Out:
# RangeIndex(start=1, stop=501, step=1)

# %%
# top500

# %% [markdown]
# ## Song recommender with 2 lists, top 100 and top 500

# %%
song_name = input("Please enter the name of a song: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    song_name = song_name.lower()

    matching_song = songs[(songs['title'].str.lower() == song_name)]

    if not matching_song.empty:
        print(f"The song '{matching_song['title'].values[0]}' by {matching_song['artist'].values[0]} matches your input.")

        recommended_song = songs[songs['title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song['title'].values[0]}' by {recommended_song['artist'].values[0]}")
    else:
        other_song = other_song = top500.sample(1)
        print(f"Here's another song that might be interesting: '{other_song['title'].values[0]}' by {other_song['artists'].values[0]}")
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: silence
# Here's another song that might be interesting: 'Subterranean Homesick Blues' by  Bob Dylan

# %% [markdown]
# ## Song recommender - improved maybe

# %%
song_name = input("Please enter the name of a song: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    song_name = song_name.lower()

    matching_song = songs[(songs['title'].str.lower() == song_name)]

    if not matching_song.empty:
        print(f"The song '{matching_song['title'].values[0]}' by {matching_song['artist'].values[0]} matches your input.")

        recommended_song = songs[songs['title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song['title'].values[0]}' by {recommended_song['artist'].values[0]}")
    else:
        other_song = other_song = top500.sample(1)
        print(f"Here's another song that might be interesting: '{other_song['title'].values[0]}' by {other_song['artists'].values[0]}")

elif not matching_song2.empty:
        print(f"The song '{matching_song2['title'].values[0]}' by {matching_song2['artist'].values[0]} matches your input.")

        recommended_song2 = top2[top2['title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song2['title'].values[0]}' by {recommended_song2['artists'].values[0]}")      
         
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: American
# Here's another song that might be interesting: 'In My Life' by The Beatles

# %% [markdown]
# # Spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
# Top 10000 id: 6sx8rpqIE3R9sfGSb8Udxy

# %%
# we will use our 'first paid music' playlist as an example:
playlist1 = sp.user_playlist_tracks("spotify", "6sx8rpqIE3R9sfGSb8Udxy")

# %%
playlist1["total"]
# Out:
# 10000

# %%
playlist1.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist1['next']
# Out:
# 'https://api.spotify.com/v1/playlists/6sx8rpqIE3R9sfGSb8Udxy/tracks?offset=100&limit=100&additional_types=track'

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist1_id):
    results = sp.user_playlist_tracks("spotify",playlist1_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
all_tracks = get_playlist_tracks("6sx8rpqIE3R9sfGSb8Udxy")
len(all_tracks)
# Out:
# 10000

# %%
from pandas import json_normalize
tracks1 = json_normalize(all_tracks)

# %%
tracks1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2018-12-04T20:49:14Z     False          None
# 1  2018-12-04T20:49:40Z     False          None
# 2  2018-12-04T20:50:06Z     False          None
# 3  2018-12-04T20:50:32Z     False          None
# 4  2018-12-04T20:51:00Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/q.c.m.olsthoorn
# 1  https://open.spotify.com/user/q.c.m.olsthoorn
# 2  https://open.spotify.com/user/q.c.m.olsthoorn
# 3  https://open.spotify.com/user/q.c.m.olsthoorn
# 4  https://open.spotify.com/user/q.c.m.olsthoorn
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 1  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 2  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 3  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 4  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:q.c.m.olsthoorn                  album
# 1          user  spotify:user:q.c.m.olsthoorn            compilation
# 2          user  spotify:user:q.c.m.olsthoorn                  album
# 3          user  spotify:user:q.c.m.olsthoorn                  album
# 4          user  spotify:user:q.c.m.olsthoorn            compilation
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local  \
# 0  4u7EnebtmKWzUH433cf5Qv          False
# 1  21cp8L9Pei4AgysZVihjSv          False
# 2  2g7gviEeJr6pyxO7G35EWQ          False
# 3  6L5BZEcZmD6RBJnimzlyKr          False
# 4  3gE5067onHssnwibln70ef          False
#
#                                       track.name track.popularity  \
# 0            Bohemian Rhapsody - Remastered 2011               83
# 1                                  Child in Time               56
# 2                Paradise By the Dashboard Light               70
# 3  Nights In White Satin - Single Version / Mono               68
# 4                                 Rain And Tears                0
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1  https://p.scdn.co/mp3-preview/dc92880be279b619...        True
# 2  https://p.scdn.co/mp3-preview/4288d070a0b94c89...        True
# 3                                               None        True
# 4                                               None        True
#
#   track.track_number track.type                             track.uri  \
# 0                 11      track  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1                  5      track  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2                  6      track  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3                 16      track  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4                  5      track  spotify:track:3gE5067onHssnwibln70ef
#
#   video_thumbnail.url
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 40 columns]

# %%
def list_to_dict(x):
    return {i: x[i] for i in range(len(x))}
            
tracks1['artist_dict'] = tracks1['track.artists'].apply(list_to_dict)
tracks1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2018-12-04T20:49:14Z     False          None
# 1  2018-12-04T20:49:40Z     False          None
# 2  2018-12-04T20:50:06Z     False          None
# 3  2018-12-04T20:50:32Z     False          None
# 4  2018-12-04T20:51:00Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/q.c.m.olsthoorn
# 1  https://open.spotify.com/user/q.c.m.olsthoorn
# 2  https://open.spotify.com/user/q.c.m.olsthoorn
# 3  https://open.spotify.com/user/q.c.m.olsthoorn
# 4  https://open.spotify.com/user/q.c.m.olsthoorn
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 1  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 2  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 3  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 4  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:q.c.m.olsthoorn                  album
# 1          user  spotify:user:q.c.m.olsthoorn            compilation
# 2          user  spotify:user:q.c.m.olsthoorn                  album
# 3          user  spotify:user:q.c.m.olsthoorn                  album
# 4          user  spotify:user:q.c.m.olsthoorn            compilation
#
#                                  track.album.artists  ... track.is_local  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...          False
#
#                                       track.name track.popularity  \
# 0            Bohemian Rhapsody - Remastered 2011               83
# 1                                  Child in Time               56
# 2                Paradise By the Dashboard Light               70
# 3  Nights In White Satin - Single Version / Mono               68
# 4                                 Rain And Tears                0
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1  https://p.scdn.co/mp3-preview/dc92880be279b619...        True
# 2  https://p.scdn.co/mp3-preview/4288d070a0b94c89...        True
# 3                                               None        True
# 4                                               None        True
#
#   track.track_number track.type                             track.uri  \
# 0                 11      track  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1                  5      track  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2                  6      track  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3                 16      track  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4                  5      track  spotify:track:3gE5067onHssnwibln70ef
#
#    video_thumbnail.url                                        artist_dict
# 0                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 1                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 2                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 3                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 4                 None  {0: {'external_urls': {'spotify': 'https://ope...
#
# [5 rows x 41 columns]

# %%
tracks1['artist_dict'] = tracks1['track.artists'].apply(list_to_dict)
tracks1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2018-12-04T20:49:14Z     False          None
# 1  2018-12-04T20:49:40Z     False          None
# 2  2018-12-04T20:50:06Z     False          None
# 3  2018-12-04T20:50:32Z     False          None
# 4  2018-12-04T20:51:00Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/q.c.m.olsthoorn
# 1  https://open.spotify.com/user/q.c.m.olsthoorn
# 2  https://open.spotify.com/user/q.c.m.olsthoorn
# 3  https://open.spotify.com/user/q.c.m.olsthoorn
# 4  https://open.spotify.com/user/q.c.m.olsthoorn
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 1  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 2  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 3  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 4  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:q.c.m.olsthoorn                  album
# 1          user  spotify:user:q.c.m.olsthoorn            compilation
# 2          user  spotify:user:q.c.m.olsthoorn                  album
# 3          user  spotify:user:q.c.m.olsthoorn                  album
# 4          user  spotify:user:q.c.m.olsthoorn            compilation
#
#                                  track.album.artists  ... track.is_local  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...          False
#
#                                       track.name track.popularity  \
# 0            Bohemian Rhapsody - Remastered 2011               83
# 1                                  Child in Time               56
# 2                Paradise By the Dashboard Light               70
# 3  Nights In White Satin - Single Version / Mono               68
# 4                                 Rain And Tears                0
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1  https://p.scdn.co/mp3-preview/dc92880be279b619...        True
# 2  https://p.scdn.co/mp3-preview/4288d070a0b94c89...        True
# 3                                               None        True
# 4                                               None        True
#
#   track.track_number track.type                             track.uri  \
# 0                 11      track  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1                  5      track  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2                  6      track  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3                 16      track  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4                  5      track  spotify:track:3gE5067onHssnwibln70ef
#
#    video_thumbnail.url                                        artist_dict
# 0                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 1                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 2                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 3                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 4                 None  {0: {'external_urls': {'spotify': 'https://ope...
#
# [5 rows x 41 columns]

# %%
def expand_list_dict1(row):
    df = pd.DataFrame.from_dict(row['artist_dict'], orient='index')
    df['song_id'] = row['track.id']
    return df

tracks1['artists_dfs'] = tracks1.apply(expand_list_dict1, axis=1)
tracks1['artists_dfs'][2]
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/7...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/7dnB1wSxbYa...  7dnB1wSxbYa8CejeVg98hz
#
#         name    type                                    uri  \
# 0  Meat Loaf  artist  spotify:artist:7dnB1wSxbYa8CejeVg98hz
#
#                   song_id
# 0  2g7gviEeJr6pyxO7G35EWQ

# %%
artist_df1 = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri'])
for val in tracks1['artists_dfs']:
    #display(val)
    artist_df1 = pd.concat([artist_df1, val], axis=0)
    
artist_df1.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 0  {'spotify': 'https://open.spotify.com/artist/5...
# 0  {'spotify': 'https://open.spotify.com/artist/7...
# 0  {'spotify': 'https://open.spotify.com/artist/5...
# 0  {'spotify': 'https://open.spotify.com/artist/2...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  1dfeR4HaWDbWqFHLkxsg1d
# 0  https://api.spotify.com/v1/artists/568ZhdwyaiC...  568ZhdwyaiCyOGJRtNYhWf
# 0  https://api.spotify.com/v1/artists/7dnB1wSxbYa...  7dnB1wSxbYa8CejeVg98hz
# 0  https://api.spotify.com/v1/artists/5BcZ22XONcR...  5BcZ22XONcRoLhTbZRuME1
# 0  https://api.spotify.com/v1/artists/2XhhAWeUOlr...  2XhhAWeUOlrZnGOB7aKEI8
#
#                 name    type                                    uri  \
# 0              Queen  artist  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
# 0        Deep Purple  artist  spotify:artist:568ZhdwyaiCyOGJRtNYhWf
# 0          Meat Loaf  artist  spotify:artist:7dnB1wSxbYa8CejeVg98hz
# 0    The Moody Blues  artist  spotify:artist:5BcZ22XONcRoLhTbZRuME1
# 0  Aphrodite's Child  artist  spotify:artist:2XhhAWeUOlrZnGOB7aKEI8
#
#                   song_id
# 0  4u7EnebtmKWzUH433cf5Qv
# 0  21cp8L9Pei4AgysZVihjSv
# 0  2g7gviEeJr6pyxO7G35EWQ
# 0  6L5BZEcZmD6RBJnimzlyKr
# 0  3gE5067onHssnwibln70ef

# %%
df_merged1 = pd.merge(left=tracks1,
                    right=artist_df1,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2018-12-04T20:49:14Z     False          None
# 1  2018-12-04T20:49:40Z     False          None
# 2  2018-12-04T20:50:06Z     False          None
# 3  2018-12-04T20:50:32Z     False          None
# 4  2018-12-04T20:51:00Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/q.c.m.olsthoorn
# 1  https://open.spotify.com/user/q.c.m.olsthoorn
# 2  https://open.spotify.com/user/q.c.m.olsthoorn
# 3  https://open.spotify.com/user/q.c.m.olsthoorn
# 4  https://open.spotify.com/user/q.c.m.olsthoorn
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 1  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 2  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 3  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 4  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:q.c.m.olsthoorn                  album
# 1          user  spotify:user:q.c.m.olsthoorn            compilation
# 2          user  spotify:user:q.c.m.olsthoorn                  album
# 3          user  spotify:user:q.c.m.olsthoorn                  album
# 4          user  spotify:user:q.c.m.olsthoorn            compilation
#
#                                  track.album.artists  ... video_thumbnail.url  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...                None
#
#                                          artist_dict  \
# 0  {0: {'external_urls': {'spotify': 'https://ope...
# 1  {0: {'external_urls': {'spotify': 'https://ope...
# 2  {0: {'external_urls': {'spotify': 'https://ope...
# 3  {0: {'external_urls': {'spotify': 'https://ope...
# 4  {0: {'external_urls': {'spotify': 'https://ope...
#
#                                          artists_dfs  \
# 0                                         externa...
# 1                                         externa...
# 2                                         externa...
# 3                                         externa...
# 4                                         externa...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 1  {'spotify': 'https://open.spotify.com/artist/5...
# 2  {'spotify': 'https://open.spotify.com/artist/7...
# 3  {'spotify': 'https://open.spotify.com/artist/5...
# 4  {'spotify': 'https://open.spotify.com/artist/2...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  1dfeR4HaWDbWqFHLkxsg1d
# 1  https://api.spotify.com/v1/artists/568ZhdwyaiC...  568ZhdwyaiCyOGJRtNYhWf
# 2  https://api.spotify.com/v1/artists/7dnB1wSxbYa...  7dnB1wSxbYa8CejeVg98hz
# 3  https://api.spotify.com/v1/artists/5BcZ22XONcR...  5BcZ22XONcRoLhTbZRuME1
# 4  https://api.spotify.com/v1/artists/2XhhAWeUOlr...  2XhhAWeUOlrZnGOB7aKEI8
#
#                 name    type                                    uri  \
# 0              Queen  artist  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
# 1        Deep Purple  artist  spotify:artist:568ZhdwyaiCyOGJRtNYhWf
# 2          Meat Loaf  artist  spotify:artist:7dnB1wSxbYa8CejeVg98hz
# 3    The Moody Blues  artist  spotify:artist:5BcZ22XONcRoLhTbZRuME1
# 4  Aphrodite's Child  artist  spotify:artist:2XhhAWeUOlrZnGOB7aKEI8
#
#                   song_id
# 0  4u7EnebtmKWzUH433cf5Qv
# 1  21cp8L9Pei4AgysZVihjSv
# 2  2g7gviEeJr6pyxO7G35EWQ
# 3  6L5BZEcZmD6RBJnimzlyKr
# 4  3gE5067onHssnwibln70ef
#
# [5 rows x 49 columns]

# %%
df_final1 = df_merged1[['track.name', 'name', 'song_id']]
df_final1.head()
# Out:
#                                       track.name               name  \
# 0            Bohemian Rhapsody - Remastered 2011              Queen
# 1                                  Child in Time        Deep Purple
# 2                Paradise By the Dashboard Light          Meat Loaf
# 3  Nights In White Satin - Single Version / Mono    The Moody Blues
# 4                                 Rain And Tears  Aphrodite's Child
#
#                   song_id
# 0  4u7EnebtmKWzUH433cf5Qv
# 1  21cp8L9Pei4AgysZVihjSv
# 2  2g7gviEeJr6pyxO7G35EWQ
# 3  6L5BZEcZmD6RBJnimzlyKr
# 4  3gE5067onHssnwibln70ef

# %%
chunks = [(i, i+100) for i in range(0, len(df_final1), 100)]
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final1['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 10644

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
df_w_audio_ft1 = pd.concat([df_final1, audio_features_df], axis=1)
df_w_audio_ft1.head()
# Out:
#                                       track.name               name  \
# 0            Bohemian Rhapsody - Remastered 2011              Queen
# 1                                  Child in Time        Deep Purple
# 2                Paradise By the Dashboard Light          Meat Loaf
# 3  Nights In White Satin - Single Version / Mono    The Moody Blues
# 4                                 Rain And Tears  Aphrodite's Child
#
#                   song_id  danceability  energy  key  loudness  mode  \
# 0  4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0    -9.928     0
# 1  21cp8L9Pei4AgysZVihjSv         0.331   0.340    9   -14.784     0
# 2  2g7gviEeJr6pyxO7G35EWQ         0.326   0.872    2    -7.602     1
# 3  6L5BZEcZmD6RBJnimzlyKr         0.195   0.483    4    -4.991     0
# 4  3gE5067onHssnwibln70ef         0.306   0.426    2   -10.943     0
#
#    speechiness  acousticness  ...  liveness  valence    tempo            type  \
# 0       0.0499         0.271  ...    0.3000    0.224   71.105  audio_features
# 1       0.0369         0.313  ...    0.2340    0.365  126.672  audio_features
# 2       0.1220         0.214  ...    0.4610    0.492  173.381  audio_features
# 3       0.0300         0.465  ...    0.0686    0.173   84.710  audio_features
# 4       0.0297         0.159  ...    0.0867    0.326   73.220  audio_features
#
#                        id                                   uri  \
# 0  4u7EnebtmKWzUH433cf5Qv  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1  21cp8L9Pei4AgysZVihjSv  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2  2g7gviEeJr6pyxO7G35EWQ  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3  6L5BZEcZmD6RBJnimzlyKr  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4  3gE5067onHssnwibln70ef  spotify:track:3gE5067onHssnwibln70ef
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1  https://api.spotify.com/v1/tracks/21cp8L9Pei4A...
# 2  https://api.spotify.com/v1/tracks/2g7gviEeJr6p...
# 3  https://api.spotify.com/v1/tracks/6L5BZEcZmD6R...
# 4  https://api.spotify.com/v1/tracks/3gE5067onHss...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4u7E...      354320
# 1  https://api.spotify.com/v1/audio-analysis/21cp...      619267
# 2  https://api.spotify.com/v1/audio-analysis/2g7g...      508333
# 3  https://api.spotify.com/v1/audio-analysis/6L5B...      269107
# 4  https://api.spotify.com/v1/audio-analysis/3gE5...      191493
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %%
df_w_audio_ft1.to_csv('filewithaudio.csv', index=False)

# %%
df1 = pd.read_csv('filewithaudio.csv')

# %%
df1.head()
# Out:
#                                       track.name               name  \
# 0            Bohemian Rhapsody - Remastered 2011              Queen
# 1                                  Child in Time        Deep Purple
# 2                Paradise By the Dashboard Light          Meat Loaf
# 3  Nights In White Satin - Single Version / Mono    The Moody Blues
# 4                                 Rain And Tears  Aphrodite's Child
#
#                   song_id  danceability  energy  key  loudness  mode  \
# 0  4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0    -9.928     0
# 1  21cp8L9Pei4AgysZVihjSv         0.331   0.340    9   -14.784     0
# 2  2g7gviEeJr6pyxO7G35EWQ         0.326   0.872    2    -7.602     1
# 3  6L5BZEcZmD6RBJnimzlyKr         0.195   0.483    4    -4.991     0
# 4  3gE5067onHssnwibln70ef         0.306   0.426    2   -10.943     0
#
#    speechiness  acousticness  ...  liveness  valence    tempo            type  \
# 0       0.0499         0.271  ...    0.3000    0.224   71.105  audio_features
# 1       0.0369         0.313  ...    0.2340    0.365  126.672  audio_features
# 2       0.1220         0.214  ...    0.4610    0.492  173.381  audio_features
# 3       0.0300         0.465  ...    0.0686    0.173   84.710  audio_features
# 4       0.0297         0.159  ...    0.0867    0.326   73.220  audio_features
#
#                        id                                   uri  \
# 0  4u7EnebtmKWzUH433cf5Qv  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1  21cp8L9Pei4AgysZVihjSv  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2  2g7gviEeJr6pyxO7G35EWQ  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3  6L5BZEcZmD6RBJnimzlyKr  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4  3gE5067onHssnwibln70ef  spotify:track:3gE5067onHssnwibln70ef
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1  https://api.spotify.com/v1/tracks/21cp8L9Pei4A...
# 2  https://api.spotify.com/v1/tracks/2g7gviEeJr6p...
# 3  https://api.spotify.com/v1/tracks/6L5BZEcZmD6R...
# 4  https://api.spotify.com/v1/tracks/3gE5067onHss...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4u7E...      354320
# 1  https://api.spotify.com/v1/audio-analysis/21cp...      619267
# 2  https://api.spotify.com/v1/audio-analysis/2g7g...      508333
# 3  https://api.spotify.com/v1/audio-analysis/6L5B...      269107
# 4  https://api.spotify.com/v1/audio-analysis/3gE5...      191493
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %%
df1.shape
# Out:
# (10644, 21)

# %%
sptracks = pd.read_csv('dataset 9.csv', index_col=0)
sptracks.shape
# Out:
# (114000, 20)

# %%
sptracks.head()
# Out:
#                  track_id                 artists                  track_name  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino                      Comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward            Ghost - Acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN              To Begin Again
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis  Can't Help Falling In Love
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet                     Hold On
#
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       230666         0.676  0.4610    1    -6.746     0       0.1430
# 1       149610         0.420  0.1660    1   -17.235     1       0.0763
# 2       210826         0.438  0.3590    0    -9.734     1       0.0557
# 3       201933         0.266  0.0596    0   -18.515     1       0.0363
# 4       198853         0.618  0.4430    2    -9.681     1       0.0526
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0        0.0322          0.000001    0.3580    0.715   87.917               4
# 1        0.9240          0.000006    0.1010    0.267   77.489               4
# 2        0.2100          0.000000    0.1170    0.120   76.332               4
# 3        0.9050          0.000071    0.1320    0.143  181.740               3
# 4        0.4690          0.000000    0.0829    0.167  119.949               4

# %%
df1.head()
# Out:
#                                       track.name               name  \
# 0            Bohemian Rhapsody - Remastered 2011              Queen
# 1                                  Child in Time        Deep Purple
# 2                Paradise By the Dashboard Light          Meat Loaf
# 3  Nights In White Satin - Single Version / Mono    The Moody Blues
# 4                                 Rain And Tears  Aphrodite's Child
#
#                   song_id  danceability  energy  key  loudness  mode  \
# 0  4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0    -9.928     0
# 1  21cp8L9Pei4AgysZVihjSv         0.331   0.340    9   -14.784     0
# 2  2g7gviEeJr6pyxO7G35EWQ         0.326   0.872    2    -7.602     1
# 3  6L5BZEcZmD6RBJnimzlyKr         0.195   0.483    4    -4.991     0
# 4  3gE5067onHssnwibln70ef         0.306   0.426    2   -10.943     0
#
#    speechiness  acousticness  ...  liveness  valence    tempo            type  \
# 0       0.0499         0.271  ...    0.3000    0.224   71.105  audio_features
# 1       0.0369         0.313  ...    0.2340    0.365  126.672  audio_features
# 2       0.1220         0.214  ...    0.4610    0.492  173.381  audio_features
# 3       0.0300         0.465  ...    0.0686    0.173   84.710  audio_features
# 4       0.0297         0.159  ...    0.0867    0.326   73.220  audio_features
#
#                        id                                   uri  \
# 0  4u7EnebtmKWzUH433cf5Qv  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1  21cp8L9Pei4AgysZVihjSv  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2  2g7gviEeJr6pyxO7G35EWQ  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3  6L5BZEcZmD6RBJnimzlyKr  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4  3gE5067onHssnwibln70ef  spotify:track:3gE5067onHssnwibln70ef
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1  https://api.spotify.com/v1/tracks/21cp8L9Pei4A...
# 2  https://api.spotify.com/v1/tracks/2g7gviEeJr6p...
# 3  https://api.spotify.com/v1/tracks/6L5BZEcZmD6R...
# 4  https://api.spotify.com/v1/tracks/3gE5067onHss...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4u7E...      354320
# 1  https://api.spotify.com/v1/audio-analysis/21cp...      619267
# 2  https://api.spotify.com/v1/audio-analysis/2g7g...      508333
# 3  https://api.spotify.com/v1/audio-analysis/6L5B...      269107
# 4  https://api.spotify.com/v1/audio-analysis/3gE5...      191493
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %%
sptracks.columns
# Out:
# Index(['track_id', 'artists', 'track_name', 'duration_ms', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['track.name', 'name', 'song_id', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
sptracks = sptracks.drop(['popularity','track_genre','explicit','album_name'], axis=1)

# %%
sptracks.head()
# Out:
#                  track_id                 artists                  track_name  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino                      Comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward            Ghost - Acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN              To Begin Again
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis  Can't Help Falling In Love
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet                     Hold On
#
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       230666         0.676  0.4610    1    -6.746     0       0.1430
# 1       149610         0.420  0.1660    1   -17.235     1       0.0763
# 2       210826         0.438  0.3590    0    -9.734     1       0.0557
# 3       201933         0.266  0.0596    0   -18.515     1       0.0363
# 4       198853         0.618  0.4430    2    -9.681     1       0.0526
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0        0.0322          0.000001    0.3580    0.715   87.917               4
# 1        0.9240          0.000006    0.1010    0.267   77.489               4
# 2        0.2100          0.000000    0.1170    0.120   76.332               4
# 3        0.9050          0.000071    0.1320    0.143  181.740               3
# 4        0.4690          0.000000    0.0829    0.167  119.949               4

# %%
df1 = df1.drop(['uri','track_href','analysis_url','id'], axis=1)

# %%
df1.head()
# Out:
#                                       track.name               name  \
# 0            Bohemian Rhapsody - Remastered 2011              Queen
# 1                                  Child in Time        Deep Purple
# 2                Paradise By the Dashboard Light          Meat Loaf
# 3  Nights In White Satin - Single Version / Mono    The Moody Blues
# 4                                 Rain And Tears  Aphrodite's Child
#
#                   song_id  danceability  energy  key  loudness  mode  \
# 0  4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0    -9.928     0
# 1  21cp8L9Pei4AgysZVihjSv         0.331   0.340    9   -14.784     0
# 2  2g7gviEeJr6pyxO7G35EWQ         0.326   0.872    2    -7.602     1
# 3  6L5BZEcZmD6RBJnimzlyKr         0.195   0.483    4    -4.991     0
# 4  3gE5067onHssnwibln70ef         0.306   0.426    2   -10.943     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0499         0.271             0.000    0.3000    0.224   71.105
# 1       0.0369         0.313             0.607    0.2340    0.365  126.672
# 2       0.1220         0.214             0.000    0.4610    0.492  173.381
# 3       0.0300         0.465             0.497    0.0686    0.173   84.710
# 4       0.0297         0.159             0.000    0.0867    0.326   73.220
#
#              type  duration_ms  time_signature
# 0  audio_features       354320               4
# 1  audio_features       619267               4
# 2  audio_features       508333               4
# 3  audio_features       269107               4
# 4  audio_features       191493               4

# %%
df1 = df1.rename(columns = {'track.name':'track_name','song_id':'track_id','name':'artists'})

# %%
df1.head()
# Out:
#                                       track_name            artists  \
# 0            Bohemian Rhapsody - Remastered 2011              Queen
# 1                                  Child in Time        Deep Purple
# 2                Paradise By the Dashboard Light          Meat Loaf
# 3  Nights In White Satin - Single Version / Mono    The Moody Blues
# 4                                 Rain And Tears  Aphrodite's Child
#
#                  track_id  danceability  energy  key  loudness  mode  \
# 0  4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0    -9.928     0
# 1  21cp8L9Pei4AgysZVihjSv         0.331   0.340    9   -14.784     0
# 2  2g7gviEeJr6pyxO7G35EWQ         0.326   0.872    2    -7.602     1
# 3  6L5BZEcZmD6RBJnimzlyKr         0.195   0.483    4    -4.991     0
# 4  3gE5067onHssnwibln70ef         0.306   0.426    2   -10.943     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0499         0.271             0.000    0.3000    0.224   71.105
# 1       0.0369         0.313             0.607    0.2340    0.365  126.672
# 2       0.1220         0.214             0.000    0.4610    0.492  173.381
# 3       0.0300         0.465             0.497    0.0686    0.173   84.710
# 4       0.0297         0.159             0.000    0.0867    0.326   73.220
#
#              type  duration_ms  time_signature
# 0  audio_features       354320               4
# 1  audio_features       619267               4
# 2  audio_features       508333               4
# 3  audio_features       269107               4
# 4  audio_features       191493               4

# %%
sptracks.columns
# Out:
# Index(['track_id', 'artists', 'track_name', 'duration_ms', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df1 = df1[['track_id', 'artists', 'track_name', 'duration_ms', 'danceability',
       'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]

# %%
X = pd.concat([df1, sptracks ], axis=0)

# %%
X.head()
# Out:
#                  track_id            artists  \
# 0  4u7EnebtmKWzUH433cf5Qv              Queen
# 1  21cp8L9Pei4AgysZVihjSv        Deep Purple
# 2  2g7gviEeJr6pyxO7G35EWQ          Meat Loaf
# 3  6L5BZEcZmD6RBJnimzlyKr    The Moody Blues
# 4  3gE5067onHssnwibln70ef  Aphrodite's Child
#
#                                       track_name  duration_ms  danceability  \
# 0            Bohemian Rhapsody - Remastered 2011       354320         0.414
# 1                                  Child in Time       619267         0.331
# 2                Paradise By the Dashboard Light       508333         0.326
# 3  Nights In White Satin - Single Version / Mono       269107         0.195
# 4                                 Rain And Tears       191493         0.306
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.404    0    -9.928     0       0.0499         0.271             0.000
# 1   0.340    9   -14.784     0       0.0369         0.313             0.607
# 2   0.872    2    -7.602     1       0.1220         0.214             0.000
# 3   0.483    4    -4.991     0       0.0300         0.465             0.497
# 4   0.426    2   -10.943     0       0.0297         0.159             0.000
#
#    liveness  valence    tempo  time_signature
# 0    0.3000    0.224   71.105               4
# 1    0.2340    0.365  126.672               4
# 2    0.4610    0.492  173.381               4
# 3    0.0686    0.173   84.710               4
# 4    0.0867    0.326   73.220               4

# %%
X.isna().sum()
# Out:
# track_id            0
# artists             1
# track_name          1
# duration_ms         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
X = X.dropna()

# %%
X.isna().sum()
# Out:
# track_id            0
# artists             0
# track_name          0
# duration_ms         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
X_num = X._get_numeric_data()

# %%
X_num.head()
# Out:
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       354320         0.414   0.404    0    -9.928     0       0.0499
# 1       619267         0.331   0.340    9   -14.784     0       0.0369
# 2       508333         0.326   0.872    2    -7.602     1       0.1220
# 3       269107         0.195   0.483    4    -4.991     0       0.0300
# 4       191493         0.306   0.426    2   -10.943     0       0.0297
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.271             0.000    0.3000    0.224   71.105               4
# 1         0.313             0.607    0.2340    0.365  126.672               4
# 2         0.214             0.000    0.4610    0.492  173.381               4
# 3         0.465             0.497    0.0686    0.173   84.710               4
# 4         0.159             0.000    0.0867    0.326   73.220               4

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(X_num)

# Now, all features will have the same weight.
pd.DataFrame(X_prep,columns=X_num.columns).head()
# Out:
#    duration_ms  danceability    energy       key  loudness      mode  \
# 0     1.220776     -0.889074 -0.932178 -1.489627 -0.309430 -1.362868
# 1     3.755100     -1.372502 -1.189477  1.040460 -1.293705 -1.362868
# 2     2.693972     -1.401624  0.949319 -0.927385  0.162033  0.733747
# 3     0.405680     -2.164624 -0.614575 -0.365144  0.691262 -1.362868
# 4    -0.336729     -1.518113 -0.843732 -0.927385 -0.515163 -1.362868
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0    -0.310149     -0.151094         -0.485119  0.465188 -1.008893 -1.707097
# 1    -0.437024     -0.023752          1.531510  0.114962 -0.471361  0.157929
# 2     0.393522     -0.323916         -0.485119  1.319527  0.012799  1.725649
# 3    -0.504366      0.437105          1.166058 -0.762725 -1.203320 -1.250464
# 4    -0.507294     -0.490673         -0.485119 -0.666679 -0.620040 -1.636110
#
#    time_signature
# 0        0.224648
# 1        0.224648
# 2        0.224648
# 3        0.224648
# 4        0.224648

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=9, random_state=1234)
kmeans.fit(X_prep)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:, 9], c=clusters,alpha=0.5)
plt.show()

# %%
import numpy as np
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    n_init='auto', 
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 15)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    n_init='auto', 
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))

plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')

# %%
# from tqdm.notebook import tqdm

# def get_playlist_tracks(playlist_id):
#     results = sp.user_playlist_tracks("spotify", playlist_id)
#     tracks = results['items']
#     count = 0  # Initialize count before the loop

#     pbar = tqdm()  # Initialize tqdm

#     while results['next'] is not None:
#         results = sp.next(results)
#         tracks = tracks + results['items']

#         sleep_time = randint(1, 3000) / 1000  # Calculate sleep time
#         sleep(sleep_time)  # respectful nap
#         count += 1  # Increment count

#         # Update tqdm progress bar
#         pbar.update(1)
#         pbar.set_postfix({'Sleep Time (seconds)': sleep_time, 'Current Count': count})

#     pbar.close()  # Close the progress bar

#     return tracks
